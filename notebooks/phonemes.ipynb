# %%
import nltk
from pycorenlp import StanfordCoreNLP
import re
import codecs
import requests
# Out:
# Hello

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a1a554e5d735> in <module>()
# ----> 1 nltk.download()
#
# C:\Program Files (x86)\Python35-32\lib\site-packages\nltk\downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error)
#     653             # function should make a new copy of self to use?
#     654             if download_dir is not None: self._download_dir = download_dir
# --> 655             self._interactive_download()
#     656             return True
#     657
#
# C:\Program Files (x86)\Python35-32\lib\site-packages\nltk\downloader.py in _interactive_download(self)
#     972         if TKINTER:
#     973             try:
# --> 974                 DownloaderGUI(self).mainloop()
#     975             except TclError:
#     976                 DownloaderShell(self).run()
#
# C:\Program Files (x86)\Python35-32\lib\site-packages\nltk\downloader.py in mainloop(self, *args, **kwargs)
#    1707
#    1708     def mainloop(self, *args, **kwargs):
# -> 1709         self.top.mainloop(*args, **kwargs)
#    1710
#    1711     #/////////////////////////////////////////////////////////////////
#
# C:\Program Files (x86)\Python35-32\lib\tkinter\__init__.py in mainloop(self, n)
#    1129     def mainloop(self, n=0):
#    1130         """Call the mainloop of Tk."""
# -> 1131         self.tk.mainloop(n)
#    1132     def quit(self):
#    1133         """Quit the Tcl interpreter. All widgets will be destroyed."""
#
# KeyboardInterrupt:

# %%
with codecs.open('../data/raw/battle-cry-army-of-the-pharaohs.txt', 'rb', encoding='utf-8', errors='ignore') as f:
    lyrics = re.sub('[^a-zA-Z0-9\n\'\[\]]', ' ', f.read()).lower()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-fa80d6d8440b> in <module>()
# ----> 1 with codecs.open('../data/raw/battle-cry-army-of-the-pharaohs.txt', 'rb', encoding='utf-8', errors='ignore') as f:
#       2     lyrics = re.sub('[^a-zA-Z0-9\n\'\[\]]', ' ', f.read()).lower()
#
# C:\Program Files (x86)\Python35-32\lib\codecs.py in open(filename, mode, encoding, errors, buffering)
#     893         # Force opening of the file in binary mode
#     894         mode = mode + 'b'
# --> 895     file = builtins.open(filename, mode, buffering)
#     896     if encoding is None:
#     897         return file
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/battle-cry-army-of-the-pharaohs.txt'

# %%
nlp = StanfordCoreNLP('http://localhost:9000')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-354b52705828> in <module>()
# ----> 1 nlp = StanfordCoreNLP('http://localhost:9000')
#
# NameError: name 'StanfordCoreNLP' is not defined

# %%
lines = [l for l in lyrics.split('\n') if (len(l) > 0 and l[0] != '[')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5bad074a9da> in <module>()
# ----> 1 lines = [l for l in lyrics.split('\n') if (len(l) > 0 and l[0] != '[')]
#
# NameError: name 'lyrics' is not defined

# %%
tokens = []
for line in lines:
    output = nlp.annotate(line, properties={
            'annotators': 'tokenize, ssplit', \
            'outputFormat': 'json' \
        })
    tokens.append([t['word'] for s in output['sentences'] for t in s['tokens']])

# %%
nltk.download()
arpabet = nltk.corpus.cmudict.dict()

base_url = 'http://www.speech.cs.cmu.edu/cgi-bin/tools/lmtool/run'

file = {'corpus': ('words.txt', " ".join([t for line in tokens for t in line if t not in arpabet.keys()]))}

res = requests.post(base_url, \
                    data={'formtype': 'simple'}, \
                    files=file, allow_redirects=True)

dict_re = re.compile(r"\d+\.dic")

dict_path = dict_re.search(res.text).group(0)

res = requests.get(res.url + dict_path)

# %%
custom_dict = {line.split('\t')[0].lower(): line.split('\t')[1].split(' ') for line in res.text.split('\n') if len(line) > 1}

# %%
def get_phonemes(word):
    try:
        return arpabet[word][0]
    except:
        try:
            return custom_dict[word]
        except:
            print(word)
            return word

phonemes = [[get_phonemes(t) for t in line] for line in tokens]

# %%
phonemes
# Out:
# [[['HH', 'AH', 'HH', 'AE', 'HH', 'AH', 'HH', 'AH']],
#  [['Y', 'AE1'],
#   ['M', 'AH', 'TH', 'AH', 'F', 'AH', 'K', 'AH', 'Z'],
#   ['W', 'IY1'],
#   ['R', 'EY1'],
#   ['B', 'AE1', 'K']],
#  [['F', 'EH1', 'R', 'OW0'],
#   ['K', 'L', 'IY1', 'K'],
#   ['M', 'AH', 'TH', 'AH', 'F', 'AH', 'K', 'AH'],
#   ['Y', 'AE1']],
#  [['D', 'EH1'],
#   ['D', 'IY1', 'V', 'IY0', 'AH0', 'S'],
#   ['K', 'IH1', 'NG'],
#   ['S', 'AY', 'Z']],
#  [['AE1', 'P', 'AH0', 'TH', 'IY0'],
#   ['S', 'EH', 'L', 'F'],
#   ['T', 'AY1', 'T', 'AH0', 'L', 'D'],
#   ['K', 'AE', 'M', 'AH', 'CH', 'IY']],
#  [['V', 'IH1', 'N', 'IY0'],
#   ['P', 'IY1'],
#   ['AW', 'T', 'ER', 'S', 'P', 'EY', 'S']],
#  [['S', 'EH', 'V', 'AH', 'N', 'EH', 'L'], ['EH1', 'S']],
#  [['AY1'],
#   ['P', 'UH1', 'T'],
#   ['Y', 'UW1'],
#   ['AH1', 'P'],
#   ['AA1', 'N'],
#   ['DH', 'AH0'],
#   ['IH', 'V'],
#   ['N', 'AA1', 'T'],
#   ['DH', 'AH0'],
#   ['R', 'OW1', 'M', 'AH0', 'N'],
#   ['N', 'UW1', 'M', 'ER0', 'AH0', 'L'],
#   ['F', 'OW', 'R']],
#  [['B', 'AH1', 'T'],
#   ['DH', 'AH0'],
#   ['IH', 'V'],
#   ['DH', 'AE1', 'T'],
#   ['L', 'IY1', 'D', 'Z'],
#   ['T', 'UW1'],
#   ['DH', 'AH0'],
#   ['F', 'Y', 'UW1', 'N', 'ER0', 'AH0', 'L'],
#   ['F', 'L', 'AO1', 'R']],
#  [['W', 'AE1', 'K', 'S'],
#   ['G', 'EH1', 'T', 'S'],
#   ['M', 'EH1', 'L', 'T', 'AH0', 'D'],
#   ['B', 'R', 'EY1', 'K', 'S'],
#   ['B', 'OW1', 'N', 'Z'],
#   ['F', 'R', 'AE1', 'K', 'CH', 'ER0', 'Z'],
#   ['P', 'EH1', 'L', 'V', 'AH0', 'S']],
#  [['S', 'P', 'IY1', 'D', 'Z'],
#   ['TH', 'R', 'UW1'],
#   ['S', 'P', 'EY1', 'S'],
#   ['AH0', 'N', 'D'],
#   ['K', 'R', 'AE1', 'K', 'S'],
#   ['G', 'L', 'AE1', 'S'],
#   ['AE1', 'S', 'T', 'R', 'AH0', 'N', 'AA2', 'T'],
#   ['HH', 'EH1', 'L', 'M', 'AH0', 'T', 'S']],
#  [['F', 'EY1', 'S'],
#   ['IH1', 'T'],
#   ['M', 'AH1', 'DH', 'ER0', 'F', 'AH1', 'K', 'ER0'],
#   ['AY1'],
#   ['K', 'AE1', 'N'],
#   ['P', 'EY1'],
#   ['T', 'UW1'],
#   ['G', 'EH1', 'T'],
#   ['R', 'IH1', 'D'],
#   ['AH1', 'V'],
#   ['Y', 'UW1']],
#  [['AY1'],
#   ['V'],
#   ['G', 'AA1', 'T'],
#   ['M', 'AO1', 'R'],
#   ['HH', 'EH1', 'D', 'Z'],
#   ['IH0', 'N'],
#   ['DH', 'AH0'],
#   ['HH', 'UH1', 'D'],
#   ['DH', 'AE1', 'N'],
#   ['P', 'EY1', 'G', 'AH0', 'N'],
#   ['R', 'IH1', 'CH', 'UW0', 'AH0', 'L', 'Z']],
#  [['AH0'],
#   ['N', 'UW1'],
#   ['T', 'ER0', 'AE1', 'N', 'IH0', 'K', 'AH0', 'L'],
#   ['F', 'AO1', 'R', 'S'],
#   ['F', 'AO1', 'R'],
#   ['Y', 'UW1'],
#   ['T', 'UW1'],
#   ['F', 'IH1', 'R']],
#  [['N', 'OW1', 'N'],
#   ['T', 'UW1'],
#   ['K', 'IH1', 'L'],
#   ['AH0', 'N', 'D'],
#   ['K', 'IY1', 'P'],
#   ['HH', 'Y', 'UW1', 'M', 'AH0', 'N'],
#   ['IH1', 'R', 'Z'],
#   ['AE1', 'Z'],
#   ['S', 'UW2', 'V', 'AH0', 'N', 'IH1', 'R', 'Z']],
#  [['AH0'],
#   ['SH', 'EY1', 'P'],
#   ['SH', 'IH1', 'F', 'T', 'ER0'],
#   ['F', 'EY1', 'S'],
#   ['S', 'L', 'IH', 'T', 'ER'],
#   ['P', 'EY1', 'P', 'ER0'],
#   ['G', 'EH1', 'T', 'ER0']],
#  [['T', 'EY1', 'P'],
#   ['Y', 'AO1', 'R'],
#   ['S', 'IH1', 'S', 'T', 'ER0'],
#   ['R', 'EY1', 'P'],
#   ['Y', 'AO1', 'R'],
#   ['S', 'IH1', 'S', 'T', 'ER0']],
#  [['M', 'EY1', 'K'],
#   ['Y', 'AO1', 'R'],
#   ['S', 'IH1', 'S', 'T', 'ER0'],
#   ['T', 'EY1', 'K'],
#   ['IH1', 'T'],
#   ['IH0', 'N'],
#   ['DH', 'AH0'],
#   ['F', 'EY1', 'S']],
#  [['AH0', 'N', 'D'],
#   ['IH1', 'F'],
#   ['Y', 'UW1'],
#   ['R'],
#   ['F', 'EY1', 'S', 'IH0', 'NG'],
#   ['AH1', 'S'],
#   ['B', 'L', 'AA1', 'K'],
#   ['AO1', 'F'],
#   ['AH0'],
#   ['TH', 'R', 'IY', 'Z', 'IY', 'R', 'OW'],
#   ['B', 'L', 'AA1', 'K'],
#   ['R', 'EY1', 'D', 'IY0', 'AH0', 'S']],
#  [['AY1'],
#   ['TH', 'R', 'OW1'],
#   ['M', 'AO1', 'R'],
#   ['B', 'L', 'OW1', 'Z'],
#   ['DH', 'AE1', 'N'],
#   ['B', 'AA1', 'K', 'S', 'IH0', 'NG'],
#   ['D', 'R', 'AY1', 'V'],
#   ['AA0', 'K', 'T', 'EY1', 'V', 'IY0', 'AH0', 'S']],
#  [['EH1', 'V', 'ER0'],
#   ['S', 'IH1', 'N', 'S'],
#   ['W', 'IY1'],
#   ['M', 'EY1', 'D'],
#   ['S', 'AH1', 'M'],
#   ['N', 'OY1', 'Z'],
#   ['AY1'],
#   ['L', 'ER1', 'N', 'D'],
#   ['P', 'IY1', 'P', 'AH0', 'L'],
#   ['L', 'AH1', 'V'],
#   ['AH0'],
#   ['W', 'IH1', 'N', 'ER0']],
#  [['W', 'IY1'],
#   ['DH', 'AH0'],
#   ['K', 'W', 'AA1', 'L', 'AH0', 'T', 'IY0'],
#   ['AH1', 'V'],
#   ['D', 'IY1', 'P'],
#   ['D', 'IH1', 'SH'],
#   ['R', 'IH1', 'M', 'Z'],
#   ['W', 'AY'],
#   ['AO1', 'L'],
#   ['DH', 'AH0'],
#   ['HH', 'AH1', 'B'],
#   ['S', 'P', 'IH1', 'N', 'ER0', 'Z']],
#  [['T', 'AH1', 'F'],
#   ['S', 'IH1', 'N', 'ER0', 'Z'],
#   ['B', 'R', 'EY1', 'K'],
#   ['B', 'R', 'EH1', 'D'],
#   ['W', 'IH1', 'DH'],
#   ['JH', 'IY1', 'Z', 'AH0', 'S'],
#   ['AE1', 'T'],
#   ['D', 'IH1', 'N', 'ER0']],
#  [['P', 'R', 'AH0', 'T', 'EH1', 'K', 'T', 'AH0', 'D'],
#   ['B', 'AY1'],
#   ['AH0'],
#   ['HH', 'EH1', 'V', 'AH0', 'N', 'L', 'IY0'],
#   ['F', 'AO1', 'R', 'S'],
#   ['F', 'AH1', 'K'],
#   ['AH0'],
#   ['M', 'IH1', 'N', 'AH0', 'S', 'T', 'ER0']],
#  [['N', 'IH', 'G', 'AH', 'Z'],
#   ['N', 'OW1'],
#   ['B', 'EH1', 'T', 'ER0'],
#   ['N', 'OW1'],
#   ['W', 'AH1', 'N'],
#   ['EH1', 'S'],
#   ['L', 'EH1', 'T', 'ER0'],
#   ['IH1', 'Z'],
#   ['B', 'EH1', 'T', 'ER0'],
#   ['DH', 'AE1', 'N'],
#   ['M', 'AY1', 'N']],
#  [['EH1', 'V', 'R', 'IY0', 'T', 'AY2', 'M'],
#   ['AY1'],
#   ['R', 'AY1', 'M'],
#   ['IH1', 'T'],
#   ['EH1', 'S'],
#   ['M', 'EH1', 'T', 'AH0', 'L'],
#   ['DH', 'AH0'],
#   ['T', 'EH1', 'R', 'ER0'],
#   ['L', 'EH1', 'V', 'AH0', 'L'],
#   ['IH1', 'Z'],
#   ['HH', 'AY1']],
#  [['P', 'L', 'AH1', 'S'],
#   ['AY1'],
#   ['T', 'EH1', 'S', 'T', 'AH0', 'F', 'AY2'],
#   ['IH1', 'T'],
#   ['EH1', 'S'],
#   ['B', 'EH1', 'S', 'T'],
#   ['Y', 'UW1'],
#   ['D', 'AY1']],
#  [['DH', 'EH1', 'N'],
#   ['F', 'AY1', 'N', 'D'],
#   ['DH', 'AH0'],
#   ['T', 'R', 'UW1', 'TH'],
#   ['D', 'IY1', 'P'],
#   ['D', 'AW1', 'N'],
#   ['IH0', 'N'],
#   ['AH0'],
#   ['M', 'AW1', 'N', 'T', 'AH0', 'N'],
#   ['AH1', 'V'],
#   ['L', 'AY1', 'Z']],
#  [['D', 'AW1', 'N', 'S', 'AY2', 'Z'],
#   ['AY1'],
#   ['AH0', 'M'],
#   ['AW1', 'S', 'T', 'IH0', 'NG'],
#   ['Y', 'UW1'],
#   ['G', 'AY1', 'Z'],
#   ['D', 'IY1', 'P'],
#   ['IH0', 'N'],
#   ['DH', 'AH0'],
#   ['D', 'ER1', 'T']],
#  [['K', 'L', 'AA1', 'K', 'IH0', 'NG'],
#   ['IH0', 'N'],
#   ['AH0', 'N', 'D'],
#   ['AW1', 'T'],
#   ['AH1', 'V'],
#   ['R', 'AE1', 'P'],
#   ['HH', 'AE1', 'V'],
#   ['W', 'AY'],
#   ['AO1', 'L'],
#   ['F', 'IY', 'N', 'D', 'IH', 'NG'],
#   ['F', 'AO1', 'R'],
#   ['W', 'ER1', 'K']],
#  [['W', 'EH1', 'N'],
#   ['AY1'],
#   ['B', 'R', 'IY1', 'D'],
#   ['IH1', 'T'],
#   ['Y', 'OW1'],
#   ['IH1', 'T'],
#   ['EH1', 'S'],
#   ['T', 'R', 'IY1', 'Z', 'AH0', 'N'],
#   ['W', 'AH1', 'T'],
#   ['DH', 'AH0'],
#   ['S', 'IY1', 'M', 'AH0', 'N'],
#   ['IH1', 'Z'],
#   ['W', 'ER1', 'TH']],
#  [['N', 'AA1', 'N'],
#   ['B', 'IH0', 'L', 'IY1', 'V', 'IH0', 'NG'],
#   ['M', 'EY1', 'K'],
#   ['M', 'IY1'],
#   ['S', 'T', 'IY1', 'M', 'IH0', 'NG'],
#   ['M', 'EY1', 'K'],
#   ['Y', 'UW1'],
#   ['M', 'IY1', 'T', 'IH0', 'NG'],
#   ['DH', 'AH0'],
#   ['ER1', 'TH']],
#  [['EY1', 'OW0'],
#   ['IH1', 'T'],
#   ['EH1', 'S'],
#   ['M', 'AY1'],
#   ['W', 'ER1', 'L', 'D'],
#   ['AH0', 'N', 'D'],
#   ['AY1'],
#   ['W', 'OW1'],
#   ['EH', 'N', 'T'],
#   ['S', 'T', 'AA1', 'P']],
#  [['AH0', 'N', 'D'],
#   ['IH1', 'F'],
#   ['Y', 'UW1'],
#   ['S', 'T', 'AE1', 'N', 'D'],
#   ['IH0', 'N'],
#   ['M', 'AY1'],
#   ['W', 'EY1'],
#   ['Y', 'UW1'],
#   ['B', 'AW1', 'N', 'D'],
#   ['T', 'UW1'],
#   ['G', 'EH1', 'T'],
#   ['P', 'AA1', 'P', 'T']],
#  [['IH0', 'N'],
#   ['DH', 'AH0'],
#   ['L', 'AE1', 'N', 'D'],
#   ['W', 'EH1', 'R'],
#   ['Y', 'UW1'],
#   ['L', 'EY1'],
#   ['IH0', 'N', 'V', 'EY1', 'D'],
#   ['F', 'R', 'AH1', 'M'],
#   ['S', 'T', 'R', 'EY1', 'T'],
#   ['SH', 'AA1', 'T', 'S']],
#  [['AY1'],
#   ['D', 'IH0', 'M', 'AE1', 'N', 'D'],
#   ['DH', 'AE1', 'T'],
#   ['Y', 'UW1'],
#   ['P', 'EY1'],
#   ['AH0', 'N', 'D'],
#   ['S', 'T', 'R', 'EY1'],
#   ['F', 'R', 'AH1', 'M'],
#   ['S', 'T', 'R', 'EY1', 'T'],
#   ['B', 'L', 'AA1', 'K', 'S']],
#  [['AY1'],
#   ['AH0', 'M'],
#   ['DH', 'AH0'],
#   ['M', 'AE1', 'N'],
#   ['DH', 'AE1', 'T'],
#   ['Y', 'UW1'],
#   ['P', 'R', 'EY1'],
#   ['D', 'UW1'],
#   ['EH', 'N', 'T'],
#   ['S', 'P', 'R', 'EY1'],
#   ['DH', 'AH0'],
#   ['F', 'L', 'EY1', 'M', 'Z'],
#   ['HH', 'AA1', 'T']],
#  [['AY1'],
#   ['K', 'UH1', 'D'],
#   ['T', 'AE1', 'N'],
#   ['IH0', 'N'],
#   ['DH', 'AH0'],
#   ['B', 'L', 'EY1', 'Z'],
#   ['F', 'AO1', 'R'],
#   ['D', 'EY1', 'Z'],
#   ['AH0', 'N', 'D'],
#   ['S', 'T', 'EY1', 'N'],
#   ['K', 'AA1', 'P', 'S']],
#  [['AY1'],
#   ['AH0', 'S', 'T', 'AW1', 'N', 'D'],
#   ['AH0', 'N', 'D'],
#   ['AH0', 'M', 'EY1', 'Z'],
#   ['W', 'AY'],
#   ['AO1', 'L'],
#   ['P', 'R', 'EY1', 'Z'],
#   ['DH', 'AH0'],
#   ['S', 'EY1', 'M'],
#   ['G', 'AA1', 'D']],
#  [['AY1'],
#   ['AH0', 'M'],
#   ['AH0'],
#   ['P', 'AW1', 'N', 'D'],
#   ['AW1', 'T'],
#   ['Y', 'AO1', 'R'],
#   ['B', 'R', 'EY1', 'N'],
#   ['AH0', 'N', 'D'],
#   ['S', 'K', 'R', 'EY1', 'P'],
#   ['DH', 'AH0'],
#   ['G', 'R', 'EY1', 'V', 'Y', 'AA2', 'R', 'D']],
#  [['HH', 'AE1', 'V'],
#   ['Y', 'UW1'],
#   ['SH', 'AW1', 'T'],
#   ['AW1', 'T'],
#   ['IH0', 'N'],
#   ['P', 'EY1', 'N'],
#   ['W', 'AY'],
#   ['AO1', 'L'],
#   ['S', 'EY1'],
#   ['W', 'AY'],
#   ['AO1', 'L'],
#   ['B', 'R', 'EY', 'V', 'HH', 'AA', 'R', 'T', 'S']],
#  [['AY1'],
#   ['AH0', 'M'],
#   ['AH0'],
#   ['B', 'AA1', 'K', 'S'],
#   ['AH1', 'P'],
#   ['Y', 'AO1', 'R'],
#   ['F', 'R', 'EY1', 'M'],
#   ['AH0', 'N', 'D'],
#   ['P', 'L', 'EY1'],
#   ['DH', 'AH0'],
#   ['S', 'EY1', 'M'],
#   ['K', 'AA1', 'R', 'D']],
#  [['AH0', 'N', 'D'],
#   ['AY1'],
#   ['AH0', 'M'],
#   ['AW1', 'T'],
#   ['F', 'AO1', 'R'],
#   ['F', 'EY1', 'M'],
#   ['S', 'P', 'EY', 'S', 'B', 'AA', 'R', 'Z'],
#   ['AH0', 'N', 'D'],
#   ['K', 'W', 'AA', 'Z', 'ER', 'Z']],
#  [['F', 'EY1', 'R', 'OW0', 'Z'],
#   ['L', 'AA1', 'K', 'T'],
#   ['DH', 'AH0'],
#   ['G', 'EY1', 'M'],
#   ['N', 'OW1'],
#   ['SH', 'EY1', 'M'],
#   ['W', 'IY1'],
#   ['HH', 'EY1', 'T'],
#   ['W', 'AY'],
#   ['AO1', 'L']],
#  [['Y', 'AE1'],
#   ['R', 'AA1'],
#   ['M', 'AH', 'TH', 'AH', 'F', 'AH', 'K', 'AH', 'N'],
#   ['R', 'AE1', 'P'],
#   ['HH', 'AA1', 'R', 'D', 'K', 'AO1', 'R'],
#   ['SH', 'IH1', 'T'],
#   ['N', 'AY1', 'N', 'T', 'IY0'],
#   ['F', 'AO1', 'R'],
#   ['SH', 'IH1', 'T']],
#  [['SH', 'UW1', 'T'],
#   ['DH', 'AH0'],
#   ['F', 'AH', 'K', 'IH', 'N'],
#   ['P', 'L', 'EY1', 'S'],
#   ['AH1', 'P'],
#   ['Y', 'AE1']],
#  [['EY', 'AH', 'T'],
#   ['B', 'L', 'AE1', 'S', 'T'],
#   ['TH', 'R', 'UW1'],
#   ['Y', 'AO1', 'R'],
#   ['AA1', 'R', 'M', 'IY0'],
#   ['F', 'AH0', 'T', 'IY1', 'G', 'Z']],
#  [['D', 'AE1', 'M', 'AH0', 'JH'],
#   ['Y', 'AO1', 'R'],
#   ['T', 'IY1', 'M'],
#   ['K', 'AA2', 'M', 'P', 'AH0', 'T', 'IH1', 'SH', 'AH0', 'N'],
#   ['D', 'AH1', 'N'],
#   ['IH1', 'T'],
#   ['W', 'IH1', 'DH'],
#   ['IY1', 'Z']],
#  [['G', 'AH1', 'N'],
#   ['IH0', 'N'],
#   ['M', 'AY1'],
#   ['S', 'L', 'IY1', 'V'],
#   ['K', 'AA1', 'Z'],
#   ['N', 'AW1'],
#   ['AH0'],
#   ['D', 'EY1', 'Z'],
#   ['HH', 'AA1', 'M', 'AH0', 'S', 'AY2', 'D'],
#   ['IH1', 'Z'],
#   ['M', 'AY1'],
#   ['S', 'T', 'IY', 'Z']],
#  [['K', 'AH0', 'L', 'EH1', 'K', 'T', 'IH0', 'NG'],
#   ['M', 'AY1'],
#   ['K', 'R', 'IY1', 'M'],
#   ['AY1'],
#   ['AH0', 'M'],
#   ['L', 'IH1', 'V', 'IH0', 'NG'],
#   ['Y', 'AO1', 'R'],
#   ['D', 'R', 'IY1', 'M'],
#   ['AH0', 'N', 'D'],
#   ['P', 'IY1', 'P', 'IH0', 'NG'],
#   ['Y', 'AO1', 'R'],
#   ['S', 'K', 'IY1', 'M']],
#  [['P', 'UH1', 'T'],
#   ['Y', 'UW1'],
#   ['AA1', 'N'],
#   ['L', 'IY1', 'N'],
#   ['F', 'R', 'AH1', 'M'],
#   ['R', 'AY1', 'T'],
#   ['HH', 'UH1', 'K', 'S'],
#   ['P', 'AO1', 'Z', 'IH0', 'NG'],
#   ['Y', 'AO1', 'R'],
#   ['JH', 'AH', 'K', 'S']],
#  [['Y', 'UW1'],
#   ['F', 'EY1', 'K'],
#   ['K', 'R', 'UH1', 'K', 'S'],
#   ['N', 'IY1', 'D'],
#   ['T', 'UW1'],
#   ['HH', 'IH1', 'T'],
#   ['DH', 'EH1', 'M'],
#   ['B', 'UH1', 'K', 'S']],
#  [['L', 'ER1', 'N'],
#   ['DH', 'AH0'],
#   ['R', 'UW1', 'L', 'Z'],
#   ['AH1', 'V'],
#   ['DH', 'AH0'],
#   ['G', 'EY1', 'M']],
#  [['T', 'UW1'],
#   ['T', 'UW1'],
#   ['Y', 'AO1', 'R'],
#   ['B', 'R', 'EY1', 'N'],
#   ['TH', 'R', 'IY1'],
#   ['T', 'UW1'],
#   ['Y', 'AO1', 'R'],
#   ['F', 'R', 'EY1', 'M'],
#   ['IH0', 'N', 'K', 'R', 'EH1', 'D', 'AH0', 'B', 'AH0', 'L'],
#   ['P', 'EY1', 'N']],
#  [['Y', 'UW1'],
#   ['G', 'EH1', 'T', 'IH0', 'NG'],
#   ['D', 'R', 'EH1', 'N', 'CH', 'T'],
#   ['IH0', 'N'],
#   ['DH', 'AE1', 'T'],
#   ['N', 'OW0', 'V', 'EH1', 'M', 'B', 'ER0'],
#   ['R', 'EY1', 'N']],
#  [['W', 'IY1'],
#   ['DH', 'AH0'],
#   ['AA1', 'P', 'AH0', 'Z', 'AH0', 'T'],
#   ['AH1', 'V'],
#   ['DH', 'AE1', 'T'],
#   ['W', 'AE1', 'K'],
#   ['SH', 'IH1', 'T']],
#  [['T', 'R', 'AE1', 'SH'],
#   ['M', 'AE1', 'N'],
#   ['AH1', 'V'],
#   ['K', 'L', 'AE1', 'P'],
#   ['R', 'AE1', 'P', 'IH0', 'NG'],
#   ['Y', 'UW1'],
#   ['D', 'AY1'],
#   ['T', 'R', 'AE1', 'SH'],
#   ['IH1', 'T']],
#  [['F', 'AY1', 'V'],
#   ['S', 'IH1', 'K', 'S'],
#   ['P', 'R', 'AH0', 'F', 'EH1', 'SH', 'AH0', 'N', 'AH0', 'L'],
#   ['AH0', 'S', 'AE1', 'S', 'AH0', 'N', 'Z']],
#  [['R', 'AA1', 'K', 'IH0', 'NG'],
#   ['DH', 'IY1', 'Z'],
#   ['M', 'IH', 'K', 'S'],
#   ['AH0', 'N', 'D'],
#   ['R', 'EH', 'P', 'IH', 'NG'],
#   ['M', 'AY1'],
#   ['F', 'AE', 'M'],
#   [''],
#   ['W', 'IH1', 'DH'],
#   ['P', 'AE1', 'SH', 'AH0', 'N']],
#  [['R', 'IH0', 'M', 'EH1', 'M', 'B', 'ER0'],
#   ['IH1', 'T', 'S'],
#   ['K', 'Y', 'UW1'],
#   ['D', 'AH0', 'M', 'EH1', 'N', 'T'],
#   [''],
#   ['Y', 'UW1'],
#   ['B', 'AE1', 'S', 'T', 'ER0', 'D', 'Z']],
#  [['T', 'EH1', 'L'],
#   ['Y', 'AO1', 'R'],
#   ['M', 'AE1', 'N'],
#   ['AH0', 'N', 'D'],
#   ['Y', 'AO1', 'R'],
#   ['P', 'EH1', 'R', 'AH0', 'N', 'T', 'S']],
#  [['W', 'IY1'],
#   ['B', 'IY1'],
#   ['D', 'IH', 'M', 'AE', 'N', 'D', 'IH', 'N'],
#   [''],
#   ['T', 'EH1', 'N'],
#   ['G', 'R', 'AE1', 'N', 'D'],
#   ['AE1', 'N'],
#   ['AH0', 'P', 'IH1', 'R', 'AH0', 'N', 'S']],
#  [['AE1', 'T'],
#   ['AH0'],
#   ['M', 'IH1', 'N', 'AH0', 'M', 'AH0', 'M'],
#   ['M', 'AY1'],
#   ['V', 'EH1', 'N', 'AH0', 'M'],
#   ['D', 'AE1', 'M', 'AH0', 'JH'],
#   ['Y', 'AO1', 'R'],
#   ['L', 'IH1', 'R', 'IH0', 'K', 'S']],
#  [['W', 'IY1'],
#   ['B', 'IY1'],
#   ['L', 'AY1', 'K'],
#   ['M', 'AE1', 'N', 'IY0'],
#   ['R', 'AH0', 'M', 'IH1', 'R', 'EH0', 'Z'],
#   ['K', 'AH1', 'M', 'Z'],
#   ['AW1', 'T'],
#   ['IH0', 'N'],
#   ['F', 'AO1', 'L']],
#  [['W', 'IH1', 'DH'],
#   ['DH', 'AH0'],
#   ['R', 'AE1', 'D', 'AH0', 'K', 'AH0', 'L'],
#   ['M', 'AE1', 'JH', 'IH0', 'K', 'AH0', 'L'],
#   ['AH0', 'N', 'D'],
#   ['IH', 'M', 'F', 'AE', 'T', 'IH', 'K', 'AH', 'L']],
#  [['AY1'],
#   [''],
#   ['M', 'AA'],
#   ['B', 'AE1', 'T', 'AH0', 'L'],
#   ['T', 'IH1', 'L'],
#   ['AY1'],
#   ['SH', 'AE1', 'T', 'ER0'],
#   ['Y', 'AO1', 'R'],
#   ['K', 'L', 'AE1', 'V', 'AH0', 'K', 'AH0', 'L']],
#  [['K', 'AO1', 'L'],
#   ['M', 'IY1'],
#   ['AE1', 'D', 'M', 'ER0', 'AH0', 'L'],
#   ['R', 'EY1', 'Z', 'IH0', 'NG'],
#   ['DH', 'AH0'],
#   ['T', 'EH1', 'M', 'P'],
#   ['AH1', 'V'],
#   ['DH', 'AH0'],
#   ['R', 'UW1', 'M']],
#  [['AY1'],
#   ['AH0', 'M'],
#   ['DH', 'AH0'],
#   ['EH1', 'M', 'P', 'ER0', 'ER0'],
#   ['R', 'IH0', 'M', 'EH1', 'M', 'B', 'ER0'],
#   ['AY1'],
#   ['N', 'EH1', 'V', 'ER0'],
#   ['S', 'ER0', 'EH1', 'N', 'D', 'ER0'],
#   ['AY1'],
#   ['D', 'IH0', 'S', 'M', 'EH1', 'M', 'B', 'ER0'],
#   ['P', 'L', 'AH0', 'T', 'UW1', 'N', 'Z']],
#  [['Y', 'AO1', 'R'],
#   ['P', 'EH1', 'T', 'IY0'],
#   ['M', 'EH1', 'N'],
#   ['AA1', 'R'],
#   ['B', 'Y', 'UW', 'F', 'UW', 'N', 'Z']],
#  [['W', 'IY1'],
#   ['S', 'EH1', 'N', 'D'],
#   ['AH0', 'M'],
#   ['T', 'UW1'],
#   ['DH', 'EH1', 'R'],
#   ['D', 'UW1', 'M'],
#   ['DH', 'AH0'],
#   ['S', 'EH1', 'K', 'AH0', 'N', 'D'],
#   ['M', 'AY1'],
#   ['V', 'EH1', 'N', 'AH0', 'M'],
#   ['EH1', 'N', 'T', 'ER0', 'Z'],
#   ['DH', 'EH1', 'R'],
#   ['W', 'UW1', 'N', 'D', 'Z']],
#  [['AY1'],
#   ['M', 'EH1', 'N', 'T', 'AH0', 'L', 'IY0'],
#   ['B', 'L', 'UW1', 'M'],
#   ['EH0', 'K', 'S', 'HH', 'Y', 'UW1', 'M'],
#   ['T', 'UW1', 'M', 'Z'],
#   ['W', 'IH1', 'DH'],
#   ['D', 'OW1', 'P'],
#   ['L', 'IH1', 'R', 'IH0', 'K', 'S']],
#  [['T', 'UW', 'P', 'IY', 'EY', 'S', 'IY'],
#   ['EH1', 'S'],
#   ['AH0', 'L', 'AY1', 'V'],
#   ['AH0', 'N', 'D'],
#   ['W', 'EH1', 'L'],
#   ['B', 'IH1', 'G'],
#   ['EH1', 'L'],
#   [''],
#   ['DH', 'AH0'],
#   ['D', 'EH1', 'V', 'AH0', 'L'],
#   ['EH1', 'S'],
#   ['S', 'AH1', 'N'],
#   [''],
#   ['R', 'AY1', 'Z'],
#   ['F', 'R', 'AH1', 'M'],
#   ['HH', 'EH1', 'L'],
#   ['W', 'IH1', 'DH'],
#   ['DH', 'OW1', 'Z'],
#   ['L', 'IH1', 'R', 'IH0', 'K', 'S']],
#  [['L', 'AY1', 'V'],
#   ['IH0', 'N'],
#   ['R', 'AH0', 'G', 'R', 'EH1', 'T'],
#   ['EY', 'AH', 'T'],
#   ['DH', 'IY1', 'Z'],
#   ['SH', 'UH1', 'K'],
#   ['R', 'AE1', 'P', 'ER0', 'Z'],
#   ['HH', 'IH1', 'T'],
#   ['DH', 'AH0'],
#   ['D', 'EH1', 'K']],
#  [['K', 'ER1', 'T', 'AH0', 'S', 'IY0'],
#   ['AH1', 'V'],
#   ['DH', 'AH0'],
#   ['S', 'T', 'R', 'IY1', 'T', 'S'],
#   ['M', 'EY1', 'K'],
#   ['IH1', 'T'],
#   ['AH0'],
#   ['M', 'AY1', 'K', 'R', 'AH0', 'F', 'OW2', 'N'],
#   ['M', 'IH1', 'D', 'AH0', 'L'],
#   ['IY1', 'S', 'T']],
#  [['M', 'AY1'],
#   ['S', 'P', 'EH1', 'SH', 'AH0', 'L', 'T', 'IY0'],
#   ['OW1', 'N', 'L', 'IY0'],
#   ['R', 'AY1', 'M', 'ER0'],
#   ['IH0', 'N', 'V', 'EH1', 'L', 'AH0', 'P', 'IH0', 'NG'],
#   ['M', 'AY1'],
#   ['L', 'IH1', 'R', 'IH0', 'K'],
#   ['SH', 'IY1', 'T', 'S']],
#  [['N', 'AA1', 'K'],
#   ['T', 'ER1', 'B', 'AH0', 'N', 'Z'],
#   ['AO1', 'F'],
#   ['AH1', 'V'],
#   ['SH', 'IY1', 'K', 'S']],
#  [['Y', 'UW1', 'S'], ['AH0'], ['P', 'AY1', 'P'], ['B', 'AA1', 'M']],
#  [['D', 'AW1', 'N', 'T', 'AW1', 'N'],
#   ['IH0', 'Z', 'R', 'EY1', 'L', 'IY0'],
#   ['B', 'UW0', 'T', 'IY1', 'K', 'S'],
#   ['F', 'UH1', 'L'],
#   ['AH1', 'V'],
#   ['D', 'EH1', 'D'],
#   ['T', 'UH1', 'R', 'AH0', 'S', 'T', 'S']],
#  [['W', 'IH1', 'DH'],
#   ['DH', 'EY1'],
#   ['D', 'R', 'IY1', 'M', 'Z'],
#   ['N', 'OW1'],
#   ['L', 'AO1', 'NG', 'G', 'ER0'],
#   ['IH0', 'N'],
#   ['AA1', 'R', 'M', 'Z'],
#   [''],
#   ['R', 'IY1', 'CH']],
#  [['DH', 'AE1', 'T'],
#   ['EH1', 'S'],
#   ['W', 'AH1', 'T'],
#   ['AY1'],
#   ['K', 'AO1', 'L'],
#   [''],
#   ['D', 'IY1', 'L', 'IH0', 'NG'],
#   ['W', 'IH1', 'DH'],
#   ['K', 'AA1', 'M'],
#   ['S', 'P', 'IY1', 'CH'],
#   ['']],
#  [['W', 'EH1', 'N'],
#   ['AY1'],
#   ['AH0', 'L', 'AA1', 'R', 'M'],
#   ['Y', 'AO1', 'R'],
#   ['P', 'IY1', 'P', 'S']],
#  [['IH0', 'N', 'S', 'K', 'R', 'AY1', 'B', 'D'],
#   ['IH0', 'N'],
#   ['AH0'],
#   ['P', 'EH1', 'Z', 'AH0', 'N', 'T'],
#   ['EH1', 'S'],
#   ['P', 'AA1', 'M'],
#   ['IH1', 'Z'],
#   ['AH0'],
#   ['B', 'L', 'EH1', 'S', 'T'],
#   ['S', 'AA1', 'L', 'M']],
#  [['IH1', 'F'],
#   ['Y', 'UW1'],
#   ['D', 'R', 'AO1'],
#   ['AH0', 'N', 'D'],
#   ['Y', 'AO1', 'R'],
#   ['W', 'EH1', 'P', 'AH0', 'N', 'Z'],
#   ['R', 'AO1', 'NG'],
#   ['DH', 'EH1', 'R'],
#   ['AY1'],
#   ['EH', 'N', 'T'],
#   ['N', 'OW1'],
#   ['S', 'T', 'EH1', 'P', 'IH0', 'NG'],
#   ['AA1', 'N']],
#  [['M', 'AY1'],
#   ['F', 'AO1', 'R', 'T', 'IY0'],
#   ['F', 'AY1', 'V'],
#   ['IH1', 'Z'],
#   ['M', 'AY1'],
#   ['W', 'EH1', 'P', 'AH0', 'N']],
#  [['M', 'AY1'],
#   ['K', 'AH1', 'L', 'CH', 'ER0'],
#   ['EH1', 'S'],
#   ['AH0'],
#   ['HH', 'OW1', 'L', 'S', 'T', 'ER0'],
#   ['W', 'IH1', 'DH'],
#   ['S', 'EH1', 'V', 'AH0', 'N'],
#   ['IH1', 'N', 'CH'],
#   ['S', 'L', 'AH1', 'G', 'Z'],
#   ['IH1', 'Z'],
#   ['K', 'EH1', 'P', 'T'],
#   ['IH0', 'N']],
#  [['S', 'K', 'W', 'EH1', 'R', 'L', 'IY0'],
#   ['AY1'],
#   ['S', 'T', 'EH1', 'P'],
#   ['IH0', 'N'],
#   ['T', 'IH1', 'L', 'T', 'IH0', 'NG'],
#   ['M', 'AY1'],
#   ['K', 'L', 'IH1', 'P', 'S'],
#   ['AH0', 'N', 'D'],
#   ['B', 'L', 'UW1'],
#   ['S', 'T', 'EH1', 'T', 'S', 'AH0', 'N']],
#  [['G', 'AA1', 'D'],
#   ['IH1', 'Z'],
#   ['M', 'AY1'],
#   ['EH1', 'S', 'AH0', 'N', 'S'],
#   ['AH0', 'N', 'D'],
#   ['Y', 'UW1'],
#   ['K', 'UH1', 'D'],
#   ['CH', 'EH1', 'K'],
#   ['DH', 'IY1', 'Z'],
#   ['R', 'AY1', 'M', 'Z'],
#   ['F', 'AO1', 'R'],
#   ['R', 'EH1', 'F', 'ER0', 'AH0', 'N', 'S']],
#  [['AH0', 'D', 'EH1', 'P', 'T'],
#   ['T', 'UW1'],
#   ['EH1', 'N', 'IY0'],
#   ['P', 'R', 'EH1', 'F', 'ER0', 'AH0', 'N', 'S'],
#   ['P', 'UH1', 'S', 'IY0']],
#  [['Y', 'AE1'],
#   ['B', 'EY1', 'B', 'IY0'],
#   ['K', 'IH1', 'NG', 'Z'],
#   ['AH1', 'V'],
#   ['DH', 'AH0'],
#   ['M', 'AH', 'DH', 'ER', 'F', 'AH', 'K', 'IH', 'N'],
#   [''],
#   ['AH1', 'N', 'D', 'ER0', 'G', 'R', 'AW2', 'N', 'D']],
#  [['W', 'AY'],
#   ['AO1', 'L'],
#   ['M', 'AH1', 'DH', 'ER0', 'F', 'AH1', 'K', 'ER0', 'Z'],
#   ['D', 'UW1'],
#   ['EH', 'N', 'T'],
#   ['W', 'AA1', 'N', 'T'],
#   ['IH1', 'T'],
#   ['W', 'IH1', 'DH'],
#   ['AH1', 'S'],
#   ['DH', 'IH1', 'S'],
#   ['DH', 'AE1', 'T'],
#   ['R', 'AA1'],
#   ['SH', 'IH1', 'T'],
#   ['TH', 'R', 'OW1', 'B', 'AE2', 'K'],
#   ['SH', 'IH1', 'T']],
#  [['AY1'],
#   ['M', 'EY1', 'K'],
#   ['IY1', 'V', 'AH0', 'L'],
#   ['K', 'AH0', 'N', 'IY1', 'V', 'AH0', 'L'],
#   ['M', 'Y', 'UW1', 'Z', 'IH0', 'K']],
#  [['AY1'],
#   ['K', 'AH1', 'M'],
#   ['TH', 'R', 'UW1'],
#   ['S', 'T', 'AH', 'N', 'T', 'IH', 'NG']],
#  [['EH1', 'V', 'ER0', 'IY0'],
#   ['V', 'ER1', 'S'],
#   ['IH1', 'Z'],
#   ['DH', 'AH0'],
#   ['S', 'EY1', 'M'],
#   ['JH', 'AH1', 'S', 'T'],
#   ['F', 'L', 'IH1', 'P', 'T'],
#   ['AH0'],
#   ['L', 'IH1', 'T', 'AH0', 'L'],
#   ['S', 'AH1', 'M', 'TH', 'IH0', 'NG'],
#   ['S', 'AH1', 'M', 'TH', 'IH0', 'NG']],
#  [['B', 'EY1', 'B', 'IY0'],
#   ['AY1'],
#   ['AH0', 'M'],
#   ['K', 'R', 'EY1', 'Z', 'IY0'],
#   ['AH0'],
#   ['K', 'R', 'EY1', 'Z', 'IY0'],
#   ['B', 'EY1', 'B', 'IY0'],
#   ['AH0'],
#   ['S', 'IH1', 'K'],
#   ['IH1', 'N', 'F', 'AH0', 'N', 'T']],
#  [['B', 'AO1', 'R', 'N'],
#   ['W', 'IH1', 'DH'],
#   ['AE1', 'N'],
#   ['IH0', 'N', 'T', 'EH1', 'N', 'T'],
#   ['T', 'UW1'],
#   ['S', 'P', 'IH1', 'T'],
#   ['S', 'L', 'IH1', 'K'],
#   ['S', 'EH1', 'N', 'T', 'AH0', 'N', 'S', 'AH0', 'Z'],
#   ['W', 'IH1', 'DH'],
#   ['S', 'IH1', 'K'],
#   ['P', 'EH', 'N', 'M', 'AE', 'N', 'SH', 'IH', 'P']],
#  [['SH', 'UW1', 'T'],
#   ['AE1', 'T'],
#   ['Y', 'AO1', 'R'],
#   ['SH', 'AH0', 'K', 'AA1', 'G', 'OW2'],
#   ['F', 'IH1', 'T', 'AH0', 'D'],
#   ['AH0', 'N', 'D'],
#   ['N', 'AA1', 'K'],
#   ['Y', 'AO1', 'R'],
#   ['S', 'AA1', 'K', 'S'],
#   ['AO1', 'F']],
#  [['EY1', 'M', 'D'],
#   ['AE1', 'T'],
#   ['Y', 'AO1', 'R'],
#   ['D', 'AO1', 'R'],
#   ['B', 'AH1', 'T'],
#   ['HH', 'IH1', 'T'],
#   ['Y', 'AO1', 'R'],
#   ['HH', 'EH1', 'D'],
#   ['SH', 'AA1', 'T'],
#   ['Y', 'AO1', 'R'],
#   ['L', 'AA1', 'K', 'S'],
#   ['AO1', 'F']],
#  [['AY1'],
#   ['HH', 'ER1', 'D'],
#   ['Y', 'UW1'],
#   ['W', 'AA1', 'Z'],
#   ['AH0', 'F', 'R', 'EY1', 'D'],
#   ['T', 'UW1'],
#   ['S', 'EY1'],
#   ['M', 'AY1'],
#   ['N', 'EY1', 'M'],
#   ['AA1', 'N'],
#   ['Y', 'AO1', 'R'],
#   ['R', 'AH0', 'K', 'AO1', 'R', 'D']],
#  [['K', 'AA1', 'Z'],
#   ['Y', 'UW1'],
#   ['EH1', 'S'],
#   ['AH0', 'F', 'R', 'EY1', 'D'],
#   ['AY1'],
#   ['D'],
#   ['P', 'UH1', 'T'],
#   ['Y', 'AO1', 'R'],
#   ['M', 'AH', 'DH', 'ER', 'F', 'AH', 'K', 'IH', 'NG'],
#   ['F', 'R', 'EY1', 'M'],
#   ['AA1', 'N'],
#   ['AH0'],
#   ['S', 'T', 'R', 'EH1', 'CH', 'ER0']],
#  [['AY1'],
#   ['K', 'AH1'],
#   ['EH', 'N', 'T'],
#   ['CH', 'EY1', 'N', 'JH'],
#   ['L', 'AO1', 'Z'],
#   ['S', 'AH1', 'N', 'Z'],
#   ['DH', 'AE1', 'T'],
#   ['EH1', 'S'],
#   ['AH0'],
#   ['G', 'AH1', 'V', 'ER0', 'M', 'AH0', 'N', 'T'],
#   ['IH1', 'SH', 'UW0']],
#  [['B', 'AH1', 'T'],
#   ['AY1'],
#   ['EH', 'L'],
#   ['B', 'R', 'EY1', 'K'],
#   ['L', 'AO1', 'Z'],
#   ['W', 'IH1', 'DH'],
#   ['AH0'],
#   ['G', 'AH1', 'N'],
#   ['DH', 'AE1', 'T'],
#   ['EH1', 'S'],
#   ['AH0'],
#   ['G', 'AH1', 'V', 'ER0', 'M', 'AH0', 'N', 'T'],
#   ['IH1', 'SH', 'UW0']],
#  [['IH1', 'T'],
#   ['EH1', 'S'],
#   ['DH', 'AH0'],
#   ['AA1', 'R', 'M', 'IY0'],
#   ['W', 'IY1'],
#   ['G', 'AA1', 'T'],
#   ['P', 'AW1', 'ER0'],
#   ['IH0', 'N'],
#   ['N', 'AH1', 'M', 'B', 'ER0', 'Z']],
#  [['AH0', 'N', 'D'],
#   ['DH', 'AE1', 'T'],
#   ['EH1', 'S'],
#   ['N', 'AY1', 'N', 'Z'],
#   ['F', 'AO1', 'R', 'T', 'IY0'],
#   ['F', 'AY1', 'V', 'Z'],
#   ['TH', 'R', 'IY1'],
#   ['F', 'AY1', 'V'],
#   ['S', 'EH1', 'V', 'AH0', 'N', 'Z'],
#   ['AH0', 'N', 'D'],
#   ['EH',
#    'M',
#    'F',
#    'AY',
#    'V',
#    'Z',
#    'IY',
#    'R',
#    'OW',
#    'Z',
#    'IY',
#    'R',
#    'OW',
#    'EH',
#    'S']],
#  [['S', 'AH1', 'M'],
#   ['P', 'IY1', 'P', 'AH0', 'L'],
#   ['S', 'EY1'],
#   ['AY1'],
#   ['AH0', 'M'],
#   ['S', 'UW0', 'P', 'IH1', 'R', 'IY0', 'ER0'],
#   ['W', 'EH1', 'N'],
#   ['AY1'],
#   ['SH', 'IH1', 'T'],
#   ['IH1', 'T']],
#  [['V', 'IH1', 'V', 'AH0', 'D'],
#   ['V', 'IH1', 'ZH', 'AH0', 'N', 'EH2', 'R', 'IY0'],
#   ['S', 'P', 'IH1', 'T'],
#   ['V', 'OW0', 'K', 'AE1', 'B', 'Y', 'AH0', 'L', 'EH2', 'R', 'IY0'],
#   ['R', 'IH0', 'D', 'IH1', 'K', 'Y', 'AH0', 'L', 'AH0', 'S']],
#  [['AY1'],
#   ['AE1', 'M'],
#   ['AH0'],
#   ['T', 'AY1', 'R', 'AH0', 'N', 'T'],
#   ['AY1'],
#   ['AH0', 'M'],
#   ['V', 'AY1', 'AH0', 'L', 'AH0', 'N', 'T'],
#   ['B', 'AY1'],
#   ['D', 'IH0', 'Z', 'AY1', 'N']],
#  [['AY1'],
#   ['S', 'AY1', 'L', 'AH0', 'N', 'S'],
#   ['DH', 'AH0'],
#   ['S', 'AY2', 'AH0', 'N', 'T', 'IH1', 'F', 'IH0', 'K'],
#   ['W', 'IH1', 'DH'],
#   ['EH1', 'V', 'ER0', 'IY0'],
#   ['L', 'AY1', 'N'],
#   ['AH1', 'V'],
#   ['DH', 'AH0'],
#   ['R', 'AY1', 'M']],
#  [['M', 'OW1', 'Z', 'AA0', 'R', 'T'],
#   ['AH1', 'V'],
#   ['S', 'T', 'R', 'IY1', 'T'],
#   ['R', 'AE1', 'P'],
#   ['B', 'R', 'EY1', 'K', 'IH0', 'NG'],
#   ['DH', 'AH0'],
#   ['B', 'AE1', 'R', 'IY0', 'ER0', 'Z']],
#  [['S', 'P', 'EY1', 'S'],
#   ['HH', 'EH1', 'R', 'IY0', 'ER0'],
#   ['F', 'IH1', 'L', 'D'],
#   ['W', 'IH1', 'DH'],
#   ['F', 'AO1', 'R', 'T', 'IY0', 'Z'],
#   ['AH0', 'N', 'D'],
#   ['P', 'IH1', 'T'],
#   ['T', 'EH1', 'R', 'IY0', 'ER0', 'Z']],
#  [['R', 'EH1', 'D', 'IY0'],
#   ['T', 'UW1'],
#   ['M', 'AE1', 'NG', 'G', 'AH0', 'L'],
#   ['EH1', 'N', 'IY0', 'B', 'AH0', 'D', 'IY0'],
#   ['K', 'R', 'AO1', 'S', 'IH0', 'NG'],
#   ['DH', 'AH0'],
#   ['L', 'AY1', 'N']],
#  [['AY1'],
#   ['S', 'AO1'],
#   ['DH', 'AH0'],
#   ['S', 'AY1', 'N'],
#   ['AH0', 'N', 'D'],
#   ['R', 'AE1', 'N'],
#   ['W', 'IH1', 'DH'],
#   ['DH', 'AH0'],
#   ['AA1', 'R', 'M', 'IY0'],
#   ['L', 'AO1', 'S', 'T'],
#   ['IH0', 'N'],
#   ['T', 'AY1', 'M']],
#  [['R', 'EH1', 'D', 'IY0'],
#   ['F', 'AO1', 'R'],
#   ['W', 'AO1', 'R'],
#   ['B', 'AH1', 'T'],
#   ['W', 'OW1'],
#   ['EH', 'N', 'T'],
#   ['R', 'AA1', 'K'],
#   ['N', 'OW1'],
#   ['D', 'IH1', 'K'],
#   ['T', 'R', 'IY1', 'Z']],
#  [['AY1'],
#   ['R', 'AA1', 'K'],
#   ['M', 'IH1', 'K'],
#   ['EH1', 'S'],
#   ['Y', 'UW1'],
#   ['TH', 'IH1', 'NG', 'K'],
#   ['IH1', 'T'],
#   ['EH1', 'S'],
#   ['AH0'],
#   ['HH', 'AH1', 'N', 'D', 'R', 'AH0', 'D'],
#   ['AH0', 'N', 'D'],
#   ['S', 'IH1', 'K', 'S', 'T', 'IY0'],
#   ['D', 'IH0', 'G', 'R', 'IY1', 'Z']],
#  [['HH', 'UW1'],
#   ['S', 'T', 'AA1', 'M', 'P'],
#   ['K', 'R', 'UW1', 'Z'],
#   ['B', 'AE1', 'T', 'ER0'],
#   ['AH0', 'N', 'D'],
#   ['B', 'R', 'UW1', 'Z'],
#   ['K', 'L', 'IH1', 'K', 'S']],
#  [['K', 'IH1', 'L'],
#   ['B', 'IH1', 'CH', 'IH0', 'Z'],
#   ['AH0', 'N', 'D'],
#   ['S', 'T', 'AE1', 'B'],
#   ['Y', 'UW1'],
#   ['T', 'R', 'IH1', 'K', 'S'],
#   ['W', 'IH1', 'DH'],
#   ['L', 'UW1', 'S'],
#   ['L', 'IH1', 'P', 'S']],
#  [['AY1'],
#   ['AH0', 'M'],
#   ['S', 'L', 'AY1', 'T', 'L', 'IY0'],
#   ['D', 'IH0', 'S', 'T', 'ER1', 'B', 'D'],
#   ['P', 'EY', 'Z', 'IY', 'N', 'Z', 'AH'],
#   ['IH1', 'Z'],
#   ['N', 'AY1', 'S'],
#   ['W', 'IH1', 'DH'],
#   ['DH', 'AH0'],
#   ['W', 'ER1', 'D', 'Z']],
#  [['DH', 'AE1', 'T'],
#   ['EH1', 'S'],
#   ['DH', 'AH0'],
#   ['R', 'IY1', 'Z', 'AH0', 'N'],
#   ['DH', 'AE1', 'T'],
#   ['AY1'],
#   ['AH0', 'M'],
#   ['F', 'L', 'AY1'],
#   ['L', 'AY1', 'K'],
#   ['DH', 'AH0'],
#   ['L', 'AY1', 'F'],
#   ['AH1', 'V'],
#   ['AH0'],
#   ['B', 'ER1', 'D']],
#  [['AY1'],
#   ['D', 'UW1'],
#   ['EH', 'N', 'T'],
#   ['K', 'EH1', 'R'],
#   ['IH1', 'F'],
#   ['Y', 'UW1'],
#   ['R'],
#   ['D', 'EH1', 'D'],
#   ['L', 'EH1', 'T'],
#   ['G', 'AA1', 'D'],
#   ['HH', 'AE1', 'V'],
#   ['Y', 'AA1']],
#  [['K', 'AA1', 'Z'],
#   ['AY1'],
#   [''],
#   ['M', 'AA'],
#   ['S', 'T', 'EY1'],
#   ['R', 'AH1', 'G', 'AH0', 'D'],
#   ['AH0', 'N', 'D'],
#   ['R', 'AA1'],
#   ['L', 'AY1', 'K'],
#   ['M', 'AA1', 'R', 'V'],
#   ['HH', 'AE1', 'G', 'L', 'ER0']],
#  [['DH', 'AE1', 'T'],
#   ['EH1', 'S'],
#   ['S', 'AH1', 'M', 'TH', 'IH0', 'NG'],
#   ['Y', 'UW1'],
#   ['D', 'UW1'],
#   ['EH', 'N', 'T'],
#   ['N', 'OW1'],
#   ['AH0', 'B', 'AW1', 'T'],
#   ['M', 'IY1'],
#   ['S', 'M', 'AO1', 'L'],
#   ['R', 'AE1', 'P', 'ER0']],
#  [['N', 'AY1', 'S'],
#   ['W', 'IH1', 'DH'],
#   ['DH', 'AH0'],
#   ['L', 'EH1', 'F', 'T'],
#   ['N', 'AY1', 'S'],
#   ['W', 'IH1', 'DH'],
#   ['DH', 'AH0'],
#   ['R', 'AY1', 'T'],
#   ['DH', 'AH0'],
#   ['JH', 'AO1'],
#   ['T', 'AE1', 'P', 'ER0']],
#  [['AA1', 'L', 'AH0'],
#   ['B', 'AE1', 'K', 'ER0'],
#   ['M', 'ER1', 'D', 'ER0'],
#   ['EH1', 'V', 'ER0', 'IY0'],
#   ['T', 'R', 'AE1', 'K'],
#   ['DH', 'AE1', 'T'],
#   ['AY1'],
#   ['AH0', 'M'],
#   ['AA1', 'N']],
#  [['Y', 'UW1'],
#   ['JH', 'AH1', 'S', 'T'],
#   ['S', 'P', 'IH1', 'T'],
#   ['AH0'],
#   ['F', 'AH1', 'K', 'IH0', 'NG'],
#   ['V', 'ER1', 'S'],
#   ['W', 'AE1', 'K'],
#   ['DH', 'EH1', 'N'],
#   ['Y', 'UW1'],
#   ['R'],
#   ['G', 'AO1', 'N']],
#  [['F', 'AH1', 'K'],
#   ['F', 'EY1', 'M'],
#   ['AY1'],
#   ['S', 'T', 'AH1', 'D', 'IY0'],
#   ['DH', 'AH0'],
#   ['F', 'EY1', 'M'],
#   ['K', 'L', 'OW1', 'S', 'L', 'IY0']],
#  [['DH', 'EY1'],
#   ['B', 'IH1', 'L', 'D'],
#   ['Y', 'UW1'],
#   ['AH1', 'P'],
#   ['DH', 'EH1', 'N'],
#   ['Y', 'UW1'],
#   ['G', 'EH1', 'T'],
#   ['R', 'AA1', 'K', 'T'],
#   ['L', 'AY1', 'K'],
#   ['SH', 'EY1', 'N'],
#   ['M', 'OW1', 'Z', 'L', 'IY0']],
#  [['IH1', 'T'],
#   ['EH1', 'S'],
#   ['P', 'EY1', 'N'],
#   ['HH', 'OW', 'M', 'IY'],
#   ['AH0', 'N', 'D'],
#   ['Y', 'AO1', 'R'],
#   ['B', 'L', 'AH1', 'D'],
#   ['AA1', 'N'],
#   ['M', 'AY1'],
#   ['P', 'EH1', 'N']],
#  [['IH1', 'T'],
#   ['EH1', 'S'],
#   ['AA1', 'R', 'M', 'IY0'],
#   ['AH1', 'V'],
#   ['DH', 'AH0'],
#   ['F', 'EY1', 'R', 'OW0', 'Z'],
#   ['AH0', 'N', 'D'],
#   ['W', 'IY1'],
#   ['R'],
#   ['F', 'L', 'AH1', 'D', 'AH0', 'D'],
#   ['W', 'IH1', 'DH'],
#   ['JH', 'EH1', 'M', 'Z']]]
